# %% [markdown]
# # I have scraped all ball by ball information from the cricinfo website for this project

# %%
import pandas as pd

# %%
df=pd.read_csv('BALL_BY_BALL.csv')

# %%
df.head()
# Out:
#    MATCH_NUMBER                    GROUND         DATE  INN  BALL  RUNS  \
# 0       1001349  Melbourne Cricket Ground  Feb 17 2017    1   0.1     0
# 1       1001349  Melbourne Cricket Ground  Feb 17 2017    1   0.2     0
# 2       1001349  Melbourne Cricket Ground  Feb 17 2017    1   0.3     1
# 3       1001349  Melbourne Cricket Ground  Feb 17 2017    1   0.4     2
# 4       1001349  Melbourne Cricket Ground  Feb 17 2017    1   0.5     0
#
#    BOWLER_ID     BOWLER_NAME BOWLER_TEAM  BATSMEN_ID     BATSMEN_NAME  \
# 0      49758  Lasith Malinga   Sri Lanka      5334.0      Aaron Finch
# 1      49758  Lasith Malinga   Sri Lanka      5334.0      Aaron Finch
# 2      49758  Lasith Malinga   Sri Lanka      5334.0      Aaron Finch
# 3      49758  Lasith Malinga   Sri Lanka      6161.0  Michael Klinger
# 4      49758  Lasith Malinga   Sri Lanka      6161.0  Michael Klinger
#
#   BATSMEN_TEAM    OUT TYPE  SPEED
# 0    Australia  False  NaN    NaN
# 1    Australia  False  NaN    NaN
# ...

# %% [markdown]
# ## New features will be calculated from the above data to create and train the model
